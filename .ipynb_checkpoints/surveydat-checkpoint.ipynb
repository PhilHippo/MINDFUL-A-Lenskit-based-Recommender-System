# %%
import pandas as pd

# %%
news = pd.read_csv('small_test_data/news.tsv',header=None,sep='\t')

# %%
news.columns=['News ID',
"Category",
"SubCategory",
"Title",
"Abstract",
"URL",
"Title Entities",
"Abstract Entities "]

# %%
# Create a DataFrame with unique subcategories
unique_subcategories = news['SubCategory'].unique()
subcategory_rows = pd.DataFrame(columns=news.columns)
# Ensure you have at least 20 unique subcategories
if len(unique_subcategories) < 20:
    print("Not enough unique subcategories.")
else:
    # Randomly shuffle the unique subcategories
    import random
    random.shuffle(unique_subcategories)
    # Filter the original DataFrame to select rows with the chosen subcategories
    for subcategory in unique_subcategories:
        subcategory_data = news[news['SubCategory'] == subcategory]
        if subcategory_data.shape[0] >= 2:
            subcategory_data = subcategory_data.head(2)
            subcategory_rows = pd.concat([subcategory_rows, subcategory_data])
        if subcategory_rows.shape[0] >= 40:
            break


# Display the selected rows
subcategory_rows
# Out:
#       News ID       Category             SubCategory  \
# 5370   N55468        finance             career-news
# 16618   N8091        finance             career-news
# 175    N61914        finance          finance-career
# 2054    N7857        finance          finance-career
# 361    N32907         health         healthagingwell
# 760    N33584         health         healthagingwell
# 21619  N50566        finance    finance-mutual-funds
# 24758  N47845        finance    finance-mutual-funds
# 1997   N20212          autos             autosreview
# 12939  N37038          autos             autosreview
# 131    N39173        finance              retirement
# 1161   N54950        finance              retirement
# 141    N63975         sports              soccer_epl
# 3244   N28867         sports              soccer_epl
# 4298   N62996         health              healthnews
# 4618   N35703         health              healthnews
# 59      N9680             tv            tv-celebrity
# 417    N50299             tv            tv-celebrity
# 2      N61837           news               newsworld
# 9      N59295           news               newsworld
# 3938   N13113  entertainment           celebritynews
# 26417  N57018  entertainment           celebritynews
# 450    N48320         sports     football_nfl_videos
# 486    N49981         sports     football_nfl_videos
# 15584  N11200             tv              tv-reviews
# 34367  N10470             tv              tv-reviews
# 23     N46481         sports             more_sports
# 70     N27435         sports             more_sports
# 3122   N39125          autos            autoscartech
# 8653   N24808          autos            autoscartech
# 3827    N1587      lifestyle  lifestylerelationships
# 4717   N22605      lifestyle  lifestylerelationships
# 79     N10886   foodanddrink      restaurantsandnews
# 80     N52386   foodanddrink      restaurantsandnews
# 8940   N52620           news      causes-environment
# 24549  N30867           news      causes-environment
# 3941   N47140          autos              autostokyo
# 12879  N29552          autos              autostokyo
# 0      N55528      lifestyle         lifestyleroyals
# 17     N55610      lifestyle         lifestyleroyals
#
#                                                    Title  \
# 5370   Job scam promising $26 an hour starts with Goo...
# 16618  Are you in a relationship with a coworker? Rea...
# 175                           50 Great Jobs for Retirees
# 2054   Walmart employees reveal how much they really ...
# 361    Now That I'm Over 50, I'm Finally Sucking It U...
# 760    Science Says Doing This One Thing for 15 Minut...
# 21619  Bank of America declares the end of the 60-40 ...
# 24758               The 25 best mutual funds of all time
# 1997   2020 Ford Mustang Shelby GT500: First Drive Re...
# 12939  Lamborghini Urus vs. Dodge Challenger Hellcat ...
# 131    5 reasons Gen Xers are struggling with retirem...
# 1161   What to do if your employer changes the terms ...
# 141    Sounders vs. Real Salt Lake, talking points: L...
# 3244           Winners & Losers: Sounders 4, FC Dallas 3
# 4298   Sausages Sold At Walmart Recalled For Possible...
# 4618   Her cancer surgery was a success. Then a genet...
# 417    [{"Label": "Kelly Ripa", "Type": "P", "Wikidat...
# 2                                                     []
# 9      [{"Label": "Chile", "Type": "G", "WikidataId":...
# 3938   [{"Label": "Diahann Carroll", "Type": "P", "Wi...
# 26417  [{"Label": "GLSEN", "Type": "O", "WikidataId":...
# 450    [{"Label": "Joe Flacco", "Type": "P", "Wikidat...
# 486    [{"Label": "Marquez Valdes-Scantling", "Type":...
# 15584                                                 []
# 34367  [{"Label": "The Little Mermaid (1989 film)", "...
# 23                                                    []
# 70     [{"Label": "Phoenix Suns", "Type": "O", "Wikid...
# 3122                                                  []
# 8653                                                  []
# 3827   [{"Label": "East Sacramento, Sacramento, Calif...
# 4717   [{"Label": "Sexless marriage", "Type": "C", "W...
# 79                                                    []
# 80                                                    []
# 8940                                                  []
# 24549  [{"Label": "Florida", "Type": "G", "WikidataId...
# 3941   [{"Label": "Tokyo Motor Show", "Type": "E", "W...
# 12879                                                 []
# 0      [{"Label": "Prince Philip, Duke of Edinburgh",...
# 17     [{"Label": "Catherine, Duchess of Cambridge", ...
#
#                                       Abstract Entities
# 5370   [{"Label": "Google Hangouts", "Type": "W", "Wi...
# 16618                                                 []
# 175    [{"Label": "Old age", "Type": "C", "WikidataId...
# 2054   [{"Label": "Glassdoor", "Type": "O", "Wikidata...
# 361                                                   []
# 760    [{"Label": "The Journal of Positive Psychology...
# 21619  [{"Label": "Bank of America", "Type": "O", "Wi...
# 24758  [{"Label": "Mutual fund", "Type": "C", "Wikida...
# 1997   [{"Label": "Shelby Mustang", "Type": "V", "Wik...
# 12939  [{"Label": "Sport utility vehicle", "Type": "C...
# 131                                                   []
# 1161                                                  []
# 141    [{"Label": "Seattle Sounders FC", "Type": "O",...
# 3244                                                  []
# 4298   [{"Label": "Walmart", "Type": "O", "WikidataId...
# 4618   [{"Label": "Fluorouracil", "Type": "U", "Wikid...
# 59     [{"Label": "Eastern Time Zone", "Type": "U", "...
# 417    [{"Label": "Kelly Ripa", "Type": "P", "Wikidat...
# 2      [{"Label": "Ukraine", "Type": "G", "WikidataId...
# 9      [{"Label": "Santiago", "Type": "G", "WikidataI...
# 3938   [{"Label": "Claudine (film)", "Type": "W", "Wi...
# 26417  [{"Label": "GLSEN", "Type": "O", "WikidataId":...
# 450    [{"Label": "Joe Flacco", "Type": "P", "Wikidat...
# 486    [{"Label": "Marquez Valdes-Scantling", "Type":...
# 15584  [{"Label": "Breaking Bad", "Type": "W", "Wikid...
# 34367  [{"Label": "American Broadcasting Company", "T...
# 23     [{"Label": "Beaver Stadium", "Type": "S", "Wik...
# 70     [{"Label": "Phoenix Suns", "Type": "O", "Wikid...
# 3122   [{"Label": "Automotive industry", "Type": "U",...
# 8653   [{"Label": "Dearborn, Michigan", "Type": "G", ...
# 3827   [{"Label": "East Sacramento, Sacramento, Calif...
# 4717                                                  []
# 79                                                    []
# 80     [{"Label": "Beyond Meat", "Type": "O", "Wikida...
# 8940   [{"Label": "Greenpeace", "Type": "O", "Wikidat...
# 24549  [{"Label": "Florida", "Type": "G", "WikidataId...
# 3941   [{"Label": "Nissan", "Type": "O", "WikidataId"...
# 12879  [{"Label": "Yui (singer)", "Type": "P", "Wikid...
# 0                                                     []
# 17     [{"Label": "Catherine, Duchess of Cambridge", ...
